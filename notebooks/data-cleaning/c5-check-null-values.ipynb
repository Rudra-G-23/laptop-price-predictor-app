# %% [markdown]
# - The amazon dataset contain the 20 pages of laptop
# - Each page one dataset it means 20 dataset
# - But we see one dataset
# - Clean fast
# - Make a notebook then script then logging
# - and clean data store for next process
# - why not using the DVC also

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as mnso
import polars as pl

# %%
path = r"C:\Users\Rudra\Desktop\laptop-price-predictor\data\amazon_laptop_1.csv"

df = pd.read_csv(path)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   product_title           22 non-null     object
#  1   rating                  21 non-null     float64
#  2   total_rating            21 non-null     object
#  3   price                   22 non-null     object
#  4   next_month_bought       17 non-null     object
#  5   offer                   21 non-null     object
#  6   mrp                     21 non-null     object
#  7   product_details_dict    22 non-null     object
#  8   brand                   22 non-null     object
#  9   model_name              22 non-null     object
#  10  screen_size             22 non-null     object
#  11  colour                  22 non-null     object
#  12  hard_disk_size          22 non-null     object
#  13  cpu_model               22 non-null     object
# ...

# %%
dl = pl.read_csv(path)

# %% [markdown]
# # Missing Value

# %%
mnso.bar(df)
# Out:
# <Axes: >

# %%
mnso.matrix(df)
# Out:
# <Axes: >

# %%
df.isnull().count()
# Out:
# product_title             22
# rating                    22
# total_rating              22
# price                     22
# next_month_bought         22
# offer                     22
# mrp                       22
# product_details_dict      22
# brand                     22
# model_name                22
# screen_size               22
# colour                    22
# hard_disk_size            22
# cpu_model                 22
# ram                       22
# os                        22
# special_features          22
# graphics_card             22
# about                     22
# technical_details_dict    22
# dtype: int64

# %%
dl.columns
# Out:
# ['product_title',
#  'rating',
#  'total_rating',
#  'price',
#  'next_month_bought',
#  'offer',
#  'mrp',
#  'product_details_dict',
#  'brand',
#  'model_name',
#  'screen_size',
#  'colour',
#  'hard_disk_size',
#  'cpu_model',
#  'ram',
#  'os',
#  'special_features',
#  'graphics_card',
#  'about',
#  'technical_details_dict']

# %%
cols = dl.columns

for col in cols:
    print(f"{col}: {dl[col].null_count()}")
# Out:
# product_title: 0
# rating: 1
# total_rating: 1
# price: 0
# next_month_bought: 5
# offer: 1
# mrp: 1
# product_details_dict: 0
# brand: 0
# model_name: 0
# screen_size: 0
# colour: 0
# hard_disk_size: 0
# cpu_model: 0
# ram: 0
# os: 0
# special_features: 1
# graphics_card: 0
# about: 0
# technical_details_dict: 0

# %%
for i in range(1, 11):
    path = fr"C:\Users\Rudra\Desktop\laptop-price-predictor\data\amazon_laptop_{i}.csv"
    print(f"\n\n\n {path}")
    
    dl = pl.read_csv(path)
    
    for col in dl.columns:
        print(f"{col}: {dl[col].null_count()}")
# Out:
#  C:\Users\Rudra\Desktop\laptop-price-predictor\data\amazon_laptop_1.csv
# product_title: 0
# rating: 1
# total_rating: 1
# price: 0
# next_month_bought: 5
# offer: 1
# mrp: 1
# product_details_dict: 0
# brand: 0
# model_name: 0
# screen_size: 0
# colour: 0
# hard_disk_size: 0
# cpu_model: 0
# ram: 0
# os: 0
# special_features: 1
# graphics_card: 0
# about: 0
# technical_details_dict: 0
#
#
#
#  C:\Users\Rudra\Desktop\laptop-price-predictor\data\amazon_laptop_2.csv
# product_title: 0
# rating: 1
# total_rating: 1
# price: 0
# next_month_bought: 9
# offer: 0
# mrp: 0
# product_details_dict: 0
# brand: 0
# model_name: 0
# screen_size: 0
# colour: 0
# hard_disk_size: 0
# cpu_model: 0
# ram: 0
# os: 0
# special_features: 0
# graphics_card: 0
# about: 0
# technical_details_dict: 0
#
#
#
#  C:\Users\Rudra\Desktop\laptop-price-predictor\data\amazon_laptop_3.csv
# product_title: 0
# rating: 2
# total_rating: 2
# price: 0
# next_month_bought: 13
# offer: 1
# mrp: 1
# product_details_dict: 0
# ...
